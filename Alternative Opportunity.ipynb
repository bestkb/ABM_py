# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from textwrap import wrap

# %matplotlib inline

pd.options.display.max_columns = 9999
np.seterr(divide="ignore");
plt.style.use('ggplot')

# %%
income = pd.read_excel("ABM_py/Lazar_fig_data.xlsx", sheet_name = "Fig2 & Fig5 & FigS2.1", header=1)
expenditure = pd.read_excel("ABM_py/Lazar_fig_data.xlsx", sheet_name = "Fig6 & FigS2.2", header=1)
employment = pd.read_excel("ABM_py/Lazar_fig_data.xlsx", sheet_name = "FigS2.4")
lazar = pd.read_excel("ABM_py/Lazar_data.xlsx", sheet_name = "Observed incomes - 2014", header=2)

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x="EmploymentType1", hue="LandSize", data=employment)

# %%
plt.figure(figsize=(10, 8))
sns.countplot(x="EmploymentType2", hue="LandSize", data=employment)

# %%
income.groupby("Livelihood type").mean().T.plot(figsize=(16, 12), colormap="Set1")

# %%
income.groupby("Livelihood type").mean().mean(axis=1)
# Out:
# Livelihood type
# FarmLabour       2933.125376
# Farming          2616.823546
# Fishing           606.513038
# ForestGoods        55.096143
# Livestock          80.869808
# Manufacturing    2900.925850
# Remittance        727.874183
# Services         4045.534974
# dtype: float64

# %%
plt.figure(figsize=(10, 8))
sns.barplot(y="Mean income (BDT/month)", x="LandSize", data=employment)

# %%
lazar.groupby("Season").sum().iloc[:, :11].plot(figsize=(14, 8), colormap="Paired")
